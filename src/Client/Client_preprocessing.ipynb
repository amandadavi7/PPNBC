# %%
import numpy as np
import pandas as pd
import csv
import os

# %%
#constants
file_path="/home/anisha/Downloads/SubjectWiseThetaPower/subject_14_thetaPower.csv"
client_count = 2
# Out:
# '/home/anisha/PPML Framework/src/Client'

# %%
df = pd.DataFrame.from_csv(file_path, header=None, index_col=None)
df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  5.942550  4.884224  4.781891  4.128901  5.202609  6.290912  9.017808
# 1  4.262595  4.226622  2.708878  2.953064  3.507946  4.810541  8.215522
# 2  4.358954  3.781681  2.737117  2.572099  3.215616  4.590899  8.142142
# 3  4.071238  3.183367  2.554965  2.316485  3.043457  4.329839  7.704967
# 4  4.603974  3.492464  3.032048  2.792421  3.651695  4.953748  8.714531
#
#          7         8         9     ...           20        21        22  \
# 0  9.315115  7.882182  7.713012    ...     0.385748  4.219013  3.559741
# 1  7.801754  9.052900  6.983002    ...     0.151396  1.911489  2.022238
# 2  7.655884  9.151985  6.831997    ...    -0.499856  1.679732  1.634302
# 3  7.170288  8.651354  6.195175    ...    -0.656005  1.685392  1.488633
# 4  8.193695  8.975594  6.583729    ...    -0.042301  2.372936  2.005395
#
#          23        24        25        26        27        28        29
# ...

# %%
#remove top 100 rows

# %%
#split data into two
